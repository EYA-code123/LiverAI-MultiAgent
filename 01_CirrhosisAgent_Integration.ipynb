# %%
# %cd /content

# !git clone https://github.com/EYA-code123/LiverAI-MultiAgent.git
# Out:
# /content
# Cloning into 'LiverAI-MultiAgent'...
# remote: Enumerating objects: 362, done.
# remote: Counting objects: 100% (187/187), done.
# remote: Compressing objects: 100% (160/160), done.
# remote: Total 362 (delta 74), reused 7 (delta 7), pack-reused 175 (from 2)
# Receiving objects: 100% (362/362), 654.83 KiB | 5.16 MiB/s, done.
# Resolving deltas: 100% (133/133), done.

# %%
# %cd /content/LiverAI-MultiAgent
# Out:
# /content/LiverAI-MultiAgent

# %%
# !find . -maxdepth 3 -type f | sort
# Out:
# ./01_Cirrhosis_Classification/DATASET/README.MD
# ./01_Cirrhosis_Classification/notebooks/Gradient_Boosting_Classifier.ipynb
# ./01_Cirrhosis_Classification/notebooks/RandomForest_Cirrhosis_Optimized.ipynb
# ./01_Cirrhosis_Classification/notebooks/XGBoost_Cirrhosis_(1).ipynb
# ./01_Cirrhosis_Classification/README.md
# ./02_Fatty_Liver_Classification/DATASET/README.MD
# ./02_Fatty_Liver_Classification/notebooks/1_LightGBM.ipynb
# ./02_Fatty_Liver_Classification/notebooks/DecisionTreeClassifier_.ipynb
# ./02_Fatty_Liver_Classification/notebooks/LightGBM.ipynb
# ./02_Fatty_Liver_Classification/notebooks/RANDOM_FOREST.ipynb
# ./02_Fatty_Liver_Classification/README.md
# ./03_Clinical_Reasoning/DATASET/README.MD
# ./03_Clinical_Reasoning/notebooks/BUPA_Liver_MLP_PyTorch (1).ipynb
# ./03_Clinical_Reasoning/notebooks/BUPA_Liver_TabNet_PyTorch (1).ipynb
# ./03_Clinical_Reasoning/notebooks/BUPA_TabTransformer_PyTorchTabular (1).ipynb
# ./03_Clinical_Reasoning/README.md
# ...

# %%
# %cd /content/LiverAI-MultiAgent

from agents.cirrhosis_agent import CirrhosisAgent

agent = CirrhosisAgent()

print("================================")
print("CIRRHOSIS AGENT")
print("================================")

print("Name:", agent.name)
print("Number of features:", len(agent.feature_names))
print("Features:")
print(agent.feature_names)
# Out:
# /content/LiverAI-MultiAgent
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2700/227712488.py in <cell line: 0>()
#       3 from agents.cirrhosis_agent import CirrhosisAgent
#       4
# ----> 5 agent = CirrhosisAgent()
#       6
#       7 print("================================")
#
# TypeError: CirrhosisAgent.__init__() missing 1 required positional argument: 'model'

# %%
# %cd /content/LiverAI-MultiAgent

print(open("agents/cirrhosis_agent.py").read())
# Out:
# /content/LiverAI-MultiAgent
# """
# Cirrhosis Agent
# Uses the trained XGBoost model for cirrhosis classification.
# """
#
# import numpy as np
#
#
# class CirrhosisAgent:
#
#     def __init__(self, model):
#         """
#         Parameters
#         ----------
#         model : trained XGBoost model
#         """
#         self.name = "CirrhosisAgent"
#         self.model_name = "XGBoost"
#         self.model = model
#
#     def predict(self, patient_data):
#         """
#         Run cirrhosis prediction.
#
#         patient_data must contain the features expected
#         by the trained XGBoost model.
#         """
#
#         X = np.asarray(patient_data)
#
#         if X.ndim == 1:
#             X = X.reshape(1, -1)
#
#         prediction = self.model.predict(X)[0]
#
#         probability = None
#
#         if hasattr(self.model, "predict_proba"):
#             probabilities = self.model.predict_proba(X)[0]
#             probability = float(np.max(probabilities))
#
# ...

# %%
import joblib

model = joblib.load(
    "models/cirrhosis/XGBoost_Cirrhosis.pkl"
)

print(type(model))
# Out:
# <class 'dict'>

# %%
print(model.keys())
# Out:
# dict_keys(['model', 'feature_names', 'numerical_columns', 'categorical_columns', 'encoders', 'target_encoder', 'numerical_imputer', 'categorical_imputer'])

# %%
xgb_model = model["model"]

print(type(xgb_model))
# Out:
# <class 'xgboost.sklearn.XGBClassifier'>

# %%
from agents.cirrhosis_agent import CirrhosisAgent

agent = CirrhosisAgent(xgb_model)

print("================================")
print("CIRRHOSIS AGENT")
print("================================")

print("Name:", agent.name)
print("Model:", agent.model_name)
# Out:
# ...
# CIRRHOSIS AGENT
# ...
# Name: CirrhosisAgent
# Model: XGBoost

# %%
print(model.keys())
# Out:
# dict_keys(['model', 'feature_names', 'numerical_columns', 'categorical_columns', 'encoders', 'target_encoder', 'numerical_imputer', 'categorical_imputer'])

# %%
xgb_model = model["model"]

print(type(xgb_model))
# Out:
# <class 'xgboost.sklearn.XGBClassifier'>

# %%
from agents.cirrhosis_agent import CirrhosisAgent

agent = CirrhosisAgent(xgb_model)

print("================================")
print("CIRRHOSIS AGENT")
print("================================")
print("Name:", agent.name)
print("Model:", agent.model_name)
# Out:
# ...
# CIRRHOSIS AGENT
# ...
# Name: CirrhosisAgent
# Model: XGBoost

# %%
print("Features utilisées par le modèle :")
print(model["feature_names"])
# Out:
# Features utilisées par le modèle :
# ['N_Days', 'Status', 'Drug', 'Age', 'Sex', 'Ascites', 'Hepatomegaly', 'Spiders', 'Edema', 'Bilirubin', 'Cholesterol', 'Albumin', 'Copper', 'Alk_Phos', 'SGOT', 'Tryglicerides', 'Platelets', 'Prothrombin']

# %%
print("Classes de la cible :")
print(model["target_encoder"].classes_)
# Out:
# Classes de la cible :
# ['1.0' '2.0' '3.0']

# %%
print("Nombre de features :", len(model["feature_names"]))
print("\nFeatures :")
for i, feature in enumerate(model["feature_names"], 1):
    print(i, "->", feature)
# Out:
# Nombre de features : 18
#
# Features :
# 1 -> N_Days
# 2 -> Status
# 3 -> Drug
# 4 -> Age
# 5 -> Sex
# 6 -> Ascites
# 7 -> Hepatomegaly
# 8 -> Spiders
# 9 -> Edema
# 10 -> Bilirubin
# 11 -> Cholesterol
# 12 -> Albumin
# 13 -> Copper
# 14 -> Alk_Phos
# 15 -> SGOT
# 16 -> Tryglicerides
# 17 -> Platelets
# 18 -> Prothrombin

# %%
# %cd /content/LiverAI-MultiAgent
# !git pull
# Out:
# /content/LiverAI-MultiAgent
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 1.94 KiB | 1.94 MiB/s, done.
# From https://github.com/EYA-code123/LiverAI-MultiAgent
#    fca3db3..2953b3a  main       -> origin/main
# Updating fca3db3..2953b3a
# Fast-forward
#  agents/cirrhosis_agent.py | 148 +++++++++++++++++++++++++++++++++++++++++-----
#  1 file changed, 132 insertions(+), 16 deletions(-)

# %%
import importlib
import agents.cirrhosis_agent

importlib.reload(agents.cirrhosis_agent)

from agents.cirrhosis_agent import CirrhosisAgent

# %%
import joblib

artifact = joblib.load(
    "models/cirrhosis/XGBoost_Cirrhosis.pkl"
)

print(artifact.keys())
# Out:
# dict_keys(['model', 'feature_names', 'numerical_columns', 'categorical_columns', 'encoders', 'target_encoder', 'numerical_imputer', 'categorical_imputer'])

# %%
agent = CirrhosisAgent(artifact)

print("Agent :", agent.name)
print("Model :", agent.model_name)
print("Features :", len(agent.feature_names))
# Out:
# Agent : CirrhosisAgent
# Model : XGBoost
# Features : 18

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !find /content/drive/MyDrive -type f -name "*.csv"
# Out:
# /content/drive/MyDrive/Colab Notebooks/5/nwtco.csv
# /content/drive/MyDrive/Colab Notebooks/5/nafld2.csv
# /content/drive/MyDrive/Colab Notebooks/5/nafld1.csv
# /content/drive/MyDrive/liver_cirrhosis_dataset.csv
# /content/drive/MyDrive/cirrhosis.csv
# /content/drive/MyDrive/.Cirrhosis Agent/DATA/liver_cirrhosis.csv
# /content/drive/MyDrive/FattyLiver Agent/DATA/nwtco.csv
# /content/drive/MyDrive/FattyLiver Agent/DATA/nafld1.csv
# /content/drive/MyDrive/FattyLiver Agent/DATA/nafld2.csv

# %%
import pandas as pd

csv_path = "/content/drive/MyDrive/.Cirrhosis Agent/DATA/liver_cirrhosis.csv"

df = pd.read_csv(csv_path)

print("Shape:", df.shape)
print(df.head())
# Out:
# Shape: (25000, 19)
#    N_Days Status     Drug    Age Sex Ascites Hepatomegaly Spiders Edema  \
# 0    2221      C  Placebo  18499   F       N            Y       N     N
# 1    1230      C  Placebo  19724   M       Y            N       Y     N
# 2    4184      C  Placebo  11839   F       N            N       N     N
# 3    2090      D  Placebo  16467   F       N            N       N     N
# 4    2105      D  Placebo  21699   F       N            Y       N     N
#
#    Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  Tryglicerides  \
# 0        0.5        149.0     4.04   227.0     598.0   52.70           57.0
# 1        0.5        219.0     3.93    22.0     663.0   45.00           75.0
# 2        0.5        320.0     3.54    51.0    1243.0  122.45           80.0
# 3        0.7        255.0     3.74    23.0    1024.0   77.50           58.0
# 4        1.9        486.0     3.54    74.0    1052.0  108.50          109.0
#
#    Platelets  Prothrombin  Stage
# ...

# %%
print(df.columns.tolist())
# Out:
# ['N_Days', 'Status', 'Drug', 'Age', 'Sex', 'Ascites', 'Hepatomegaly', 'Spiders', 'Edema', 'Bilirubin', 'Cholesterol', 'Albumin', 'Copper', 'Alk_Phos', 'SGOT', 'Tryglicerides', 'Platelets', 'Prothrombin', 'Stage']

# %%
import joblib
from agents.cirrhosis_agent import CirrhosisAgent

artifact = joblib.load(
    "models/cirrhosis/XGBoost_Cirrhosis.pkl"
)

agent = CirrhosisAgent(artifact)

print("Agent :", agent.name)
print("Modèle :", agent.model_name)
print("Features :", len(agent.feature_names))
# Out:
# Agent : CirrhosisAgent
# Modèle : XGBoost
# Features : 18

# %%
patient = df.drop(columns=["Stage"]).iloc[0].to_dict()

print(patient)
# Out:
# {'N_Days': 2221, 'Status': 'C', 'Drug': 'Placebo', 'Age': 18499, 'Sex': 'F', 'Ascites': 'N', 'Hepatomegaly': 'Y', 'Spiders': 'N', 'Edema': 'N', 'Bilirubin': 0.5, 'Cholesterol': 149.0, 'Albumin': 4.04, 'Copper': 227.0, 'Alk_Phos': 598.0, 'SGOT': 52.7, 'Tryglicerides': 57.0, 'Platelets': 256.0, 'Prothrombin': 9.9}

# %%
result = agent.predict(patient)

print("================================")
print("RESULTAT")
print("================================")

print(result)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2700/2447769947.py in <cell line: 0>()
# ----> 1 result = agent.predict(patient)
#       2
#       3 print("================================")
#       4 print("RESULTAT")
#       5 print("================================")
#
# /content/LiverAI-MultiAgent/agents/cirrhosis_agent.py in predict(self, patient_data)
#      90             df[self.numerical_columns] = (
#      91                 self.numerical_imputer.transform(
# ---> 92                     df[self.numerical_columns]
#      93                 )
#      94             )
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
# ...

# %%
# %cd /content/LiverAI-MultiAgent
# !git pull
# Out:
# /content/LiverAI-MultiAgent
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 3), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 1.71 KiB | 1.71 MiB/s, done.
# From https://github.com/EYA-code123/LiverAI-MultiAgent
#    2953b3a..3c1e3d9  main       -> origin/main
# Updating 2953b3a..3c1e3d9
# Fast-forward
#  agents/cirrhosis_agent.py | 153 ++++++++++++++++++++++++++++++----------------
#  1 file changed, 102 insertions(+), 51 deletions(-)

# %%
import importlib
import agents.cirrhosis_agent

importlib.reload(agents.cirrhosis_agent)

from agents.cirrhosis_agent import CirrhosisAgent

# %%
import joblib

artifact = joblib.load(
    "models/cirrhosis/XGBoost_Cirrhosis.pkl"
)

agent = CirrhosisAgent(artifact)

# %%
patient = df.drop(columns=["Stage"]).iloc[0].to_dict()

# %%
result = agent.predict(patient)

print("================================")
print("RESULTAT CIRRHOSIS AGENT")
print("================================")

print(result)
# Out:
# ...
# RESULTAT CIRRHOSIS AGENT
# ...
# {'agent': 'CirrhosisAgent', 'model': 'XGBoost', 'prediction': '1.0', 'probability': 0.8047369122505188, 'status': 'completed'}
